# %% [markdown]
# <a href="https://colab.research.google.com/github/sindhura-nk/Artificial-Intelligence_2_1377/blob/main/Facebook_Prophet_Model_for_TSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Facebook Prophet Model

# %%
pip install prophet

# %%
from prophet import Prophet
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define a function to generate seasonal data
def generate_seasonal_data(start_date, period, seasonality_factor):
    data = pd.DataFrame({
        "ds": pd.date_range(start_date, periods=period, freq="D")
    })
    data["y"] = np.sin(2 * np.pi * data["ds"].dt.dayofyear / 365) * seasonality_factor # This creates a smooth sine wave across the year → mimicking yearly seasonality.
    return data

# %% [markdown]
# prophet model needs column names ds for dates and y for years

# %%
# Generate data with a yearly seasonality pattern
data = generate_seasonal_data("2020-01-01", 365, 10)  # 1 year of data with seasonality factor of 10

# %%
data
# Out:
#             ds             y
# 0   2020-01-01  1.721336e-01
# 1   2020-01-02  3.442161e-01
# 2   2020-01-03  5.161967e-01
# 3   2020-01-04  6.880243e-01
# 4   2020-01-05  8.596480e-01
# ..         ...           ...
# 360 2020-12-26 -6.880243e-01
# 361 2020-12-27 -5.161967e-01
# 362 2020-12-28 -3.442161e-01
# 363 2020-12-29 -1.721336e-01
# 364 2020-12-30  6.432491e-15
#
# [365 rows x 2 columns]

# %%
# Forecast for the next 2 years (730 days)
future = data.copy()
future["ds"] = future["ds"] + pd.DateOffset(days=730)  # Extend data for forecasting

# %%
future
# Out:
#             ds             y
# 0   2021-12-31  1.721336e-01
# 1   2022-01-01  3.442161e-01
# 2   2022-01-02  5.161967e-01
# 3   2022-01-03  6.880243e-01
# 4   2022-01-04  8.596480e-01
# ..         ...           ...
# 360 2022-12-26 -6.880243e-01
# 361 2022-12-27 -5.161967e-01
# 362 2022-12-28 -3.442161e-01
# 363 2022-12-29 -1.721336e-01
# 364 2022-12-30  6.432491e-15
#
# [365 rows x 2 columns]

# %%
# Create and fit the Prophet model
model = Prophet()
model.fit(data)

# Make the forecast
forecast = model.make_future_dataframe(periods=730)  # Forecast for 2 years
forecast = model.predict(forecast)

# Plot the actual data and forecast
model.plot(forecast, figsize=(12, 6))
model.plot_components(forecast)  # View separate components of the forecast

# Show the plot
plt.show()
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmppflz0jrv/g4ihaoyy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmppflz0jrv/0u9u_fwo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28575', 'data', 'file=/tmp/tmppflz0jrv/g4ihaoyy.json', 'init=/tmp/tmppflz0jrv/0u9u_fwo.json', 'output', 'file=/tmp/tmppflz0jrv/prophet_modelk8tr4vzl/prophet_model-20250909044630.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 04:46:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:46:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
forecast
# Out:
#              ds      trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0    2020-01-01   0.352648    0.135814    0.581937     0.352648     0.352648
# 1    2020-01-02   0.508745    0.270628    0.733929     0.508745     0.508745
# 2    2020-01-03   0.664842    0.440021    0.900693     0.664842     0.664842
# 3    2020-01-04   0.820938    0.595038    1.050361     0.820938     0.820938
# 4    2020-01-05   0.977035    0.739813    1.203136     0.977035     0.977035
# ...         ...        ...         ...         ...          ...          ...
# 1090 2022-12-26  93.492907  -34.238420  222.045972   -34.113299   221.878889
# 1091 2022-12-27  93.622666  -34.240490  222.072198   -34.145097   222.369773
# 1092 2022-12-28  93.752425  -34.643902  222.570770   -34.463956   222.858925
# 1093 2022-12-29  93.882184  -34.664339  222.756809   -34.782816   223.133394
# 1094 2022-12-30  94.011943  -35.032463  223.468793   -35.101676   223.372766
#
# ...
